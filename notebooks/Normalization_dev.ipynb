# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt

# %%
from IrisLocalization import *
from IrisNormalization import *

# %%
img = cv2.imread('CASIA Iris Image Database (version 1.0)/004/1/004_1_1.bmp')

incir, outcir = Localization(img)
normImg = Normalization(img, incir, outcir)
plt.imshow(normImg, cmap='gray')
